# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %% [markdown]
# # Optimization 1
# Will keep the name column to see its relevance

# %%
# Drop the non-beneficial ID columns, 'EIN'.
application_df = application_df.drop(columns=['EIN'])

# %%
# Determine the number of unique values in each column.
unique_values = application_df.nunique()

print(unique_values)
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
#Look at NAME value counts for binning
name_vc= application_df["NAME"].value_counts()
name_vc

#Choose a cutoff value and create a list of name_replace to be replaced
#use variable name: name_replace
name_replace= list(name_vc[name_vc<10].index)
name_replace
# Out:
# ['HEALTH CARE FOR ALL-CALIFORNIA',
#  'PHI ETA SIGMA NATIONAL HONOR SOCIETY INC',
#  'RECREATION CENTERS OF SUN CITY INC',
#  'ASSOCIATION OF SCHOOL BOOSTER CLUBS',
#  'INTERNATIONAL SOCIETY DAUGHTERS OF UTAH PIONEERS',
#  'SOUTHERN OFF ROAD BICYCLE ASSOCIATION',
#  'OREGON EDUCATION ASSOCIATION',
#  'NATIONAL CHRISTIAN CHARITABLE FOUNDATION INC',
#  'NATIONAL COUNCIL OF NEGRO WOMEN INC',
#  'INDEPENDENT ELECTRICAL CONTRACTORS INC',
#  'PAGAN PRIDE PROJECT INC',
#  'TUSKEGEE AIRMEN INC',
#  'ALPHA PHI OMEGA',
#  'SEATTLE CHILDRENS HOSPITAL',
#  'FBI NATIONAL CITIZENS ACADEMY ALUMNI ASSOCIATION INC',
#  'UNITED OSTOMY ASSOCIATIONS OF AMERICA INC',
#  'AMERICAN CHEMICAL SOCIETY',
#  'MILITARY ORDER OF THE WORLD WARS',
#  'PTA FLORIDA CONGRESS',
#  'NATIONAL LEAGUE OF YOUNG MEN INC',
#  'AMERICAN HIBISCUS',
#  'AMERICAN VOLKSSPORT ASSOCIATION INC',
#  'THETA NU XI MULTICULTURAL SORORITY INC',
#  'QUOTA CLUB INTERNATIONAL INC',
#  'AMERICAN INSTITUTE OF GRAPHIC ARTS',
#  'AFRICAN-AMERICAN POSTAL LEAGUE UNITED FOR SUCCESS A-PLUS',
#  'SHRINERS INTERNATIONAL',
#  'PTA OKLAHOMA CONGRESS',
#  'VICTORY NEW TESTAMENT FELLOWSHIP INTERNATIONAL',
#  'NATIONAL NETWORK OF ABORTION FUNDS',
#  'NATIONAL LEAGUE OF AMERICAN PEN WOMEN INC',
#  'LEWIS AND CLARK TRAIL HERITAGE FOUNDATION INC',
#  'GEORGIA EXTENSION 4-H FOUNDATION',
#  'SOCIETY FOR CREATIVE ANACHRONISM INC',
#  'PHI DELTA EPSILON MEDICAL FRATERNITY INC',
#  'WYOMING CONGRESS OF PARENT AND TEACHERS ASSOCIATION',
#  'ALPHA SIGMA PHI FRATERNITY INC',
#  'CIRCLE K INTERNATIONAL INC',
#  'ICE AGE FLOODS INSTITUTE',
#  'YOUNG PROFESSIONALS IN TRANSPORTATION',
#  'UNITED DAUGHTERS OF THE CONFEDERACY',
#  'VIETNAM VETERANS OF AMERICA INC',
#  'NATIONAL SOCIETY DAUGHTERS OF THE BRITISH EMPIRE IN THE UNITED STATE',
#  'CAJUN FRENCH MUSIC ASSOCIATION OF LOUISIANA INC',
#  'SOUTHERN CALIFORNIA OUTRIGGER RACING ASSOCIATION',
#  'JAPANESE AMERICAN CITIZENS LEAGUE',
#  'WOMENS OVERSEAS SERVICE LEAGUE',
#  'HOLIDAY RAMBLER RECREATIONAL VECHICLE CLUB INC',
#  'FALLON COUNTY 4-H COUNCIL',
#  'VFW AUXILIARY DEPT OF HAWAII',
#  'CHIEF WARRANT & WARRANT OFFICERS ASSOCIATION U S COAST GUARD',
#  'COMMUNICATION WORKERS OF AMERICA',
#  'TANNER MEDICAL CENTER',
#  'BLUE KNIGHTS MOTORCYCLE CLUB',
#  'INTERNATIONAL ASSOCIATION OF JEWISH GENEALOGICAL SOCIETIES INC',
#  'SPIRITHORSE THERAPEUTIC RIDING CENTER',
#  'HOUSTON SQUARE & ROUND DANCE COUNCIL',
#  'EMMAUS CALLING INC',
#  'RURAL COMMUNITY HOUSING DEVELOPMENT CORPORATION',
#  'NATL SOCIETY WOMEN DESCENDANTS OF THE ANCIENT & HONORABLE ARTILLERY',
#  'ASSOCIATES OF VIETNAM VETERANS OF AMERICA INC',
#  'UNITED STATES FENCING ASSOCIATION',
#  'ESCAPEES SOCIAL NETWORK',
#  'BARNABAS GROUP INC',
#  'ORDER OF THE AMARANTH INC',
#  'KIRKWOOD SCHOOL DISTRICT PARENT TEACHER ORGANIZATIONAL COUNCIL',
#  'BEREAVED PARENTS OF THE USA',
#  'TEXAS GARDEN CLUBS INC',
#  'AACE INTERNATIONAL',
#  'INTERNATIONAL ASSOCIATION FOR PUBLIC PARTICIPATION USA',
#  'NATIONAL COUNCIL OF TEACHERS OF ENGLISH',
#  'MYTEAM TRIUMPH INC',
#  'THETA TAU FRATERNITY',
#  'ALBANY STATE UNIVERSITY NATIONAL ALUMNI ASSOCIATION',
#  'VETERANS OF FOREIGN WARS DEPARTMENT OF CALIFORNIA',
#  'NU RHO PSI-THE NATIONAL HONOR SOCIETY IN NEUROSCIENCE',
#  'RCI INC',
#  'CONCERNS OF POLICE SURVIVORS',
#  'THETA CHI EPSILON SORORITY OF N A',
#  'CREATIVE OPPORTUNITIES UNLIMITED',
#  'NATIONAL ASSOCIATION OF CORPORATE DIRECTORS',
#  'CHRISTIAN MEDICAL & DENTAL SOCIETY',
#  'TEXAS 4-H',
#  'NATIONAL SOCIETY COLONIAL DAUGHTERS OF THE SEVENTEENTH CENTURY',
#  'ZETA PHI BETA SORORITY',
#  'US COMMITTEE FOR UN FUND FOR WOMEN INC',
#  'TENNESSEE FOSTER CARE ASSOCIATION INC',
#  'NATIONAL KAPPA KAPPA IOTA INC',
#  'KAPPA KAPPA PSI FRATERNITY',
#  'UNIVERSITY OF FLORIDA ALUMNI ASSOCIATION INC',
#  'NATIONAL SOCIETY OF THE SONS OF THE AMERICAN REVOLUTION',
#  'NATIONAL RURAL LETTER CARRIERS ASSOCIATION',
#  'NATIONAL CHARITY LEAGUE',
#  'KIWANIS INTERNATIONAL',
#  'OFFICE AND PROFESSIONAL EMPLOYEES INTERNATIONAL UNION',
#  'MENNONITE DISASTER SERVICE',
#  'AMERICAN INDEPENDENT BUSINESS ALLIANCE',
#  'FULBRIGHT ASSOCIATION INC',
#  'THE INTERIOR DESIGN SOCIETY INC',
#  'QUAIL FEDERATION INC',
#  'WASHINGTON SOCIETY OF PROFESSIONAL ENGINEERS',
#  'FREE & ACCEPTED MASONS OF TENNESSEE',
#  'FLEET RESERVE ASSOCIATION',
#  'DAUGHTERS OF CHARITY HEALTH SYSTEM',
#  'NATIONAL CHARITY LEAGUE INC',
#  'THE READING FOUNDATION',
#  'INTERNATIONAL CONGRESS OF CHURCHES MINISTERS',
#  'DEPARTMENT OF OREGON LADIES AUXILLARY TO THE VFW OF THE US',
#  'PARENTS OF MURDERED CHILDREN',
#  'PUBLIC RELATIONS COUNCIL OF ALABAMA',
#  'JACKSONVILLE DISTRICT COUNCIL SOCIETY OF ST VINCENT DE PAUL INC',
#  'UNITED STATES POWER SQUADRONS',
#  'HANDS FOR LIFE',
#  'GOLD WING ROAD RIDERS ASSOCIATION',
#  'FREE & ACCEPTED MASONS OF GEORGIA',
#  'SOCIETY FOR CREATIVE ANACHRONISM',
#  'REFRIGERATION SERVICE ENGINEERS SOCIETY',
#  'DAMAGE PREVENTION COUNCIL OF TEXAS',
#  'MONTANA CONGRESS OF PARENTS TEACHERS STUDENTS',
#  'AMERICAN SOCIETY OF ADDICTION MEDICINE INC',
#  'BETA BETA BETA BIOLOGICAL SOCIETY',
#  'DELTA KAPPA GAMMA SOCIETY INTERNATIONAL',
#  'HUGH OBRIAN YOUTH LEADERSHIP',
#  'EAST VIEW SPORTS COALITION',
#  'FAMILY CAREER AND COMMUNITY LEADERS OF AMERICA INC',
#  'HABITAT FOR HUMANITY INTERNATIONAL',
#  'TEXAS FEDERATION OF WOMEN CLUBS',
#  'OLD OAK CLIFF CONSERVATION LEAGUE INC',
#  'AMERICAN NEPHROLOGY NURSES ASSOCIATION',
#  'HUMBLE ISD EDUCATIONAL SUPPORT GROUPS INC',
#  'PROFESSIONAL LOADMASTER ASSOCIATION',
#  'CBMC INC',
#  'FLORIDA FAMILY CHILD CARE HOME ASSOCIATION INC',
#  'GERONTOLOGICAL ADVANCED PRACTICE NURSES ASSOCIATION',
#  'INTERNATIONL TRANSPLANT NURSES SOCIETY',
#  'NATIONAL ORGANIZATION FOR WOMEN INC',
#  'PTA HAWAII CONGRESS',
#  'HIGH TWELVE INTERNATIONAL',
#  'CHILDRENS HEART FOUNDATION',
#  'INTERNATIONAL ORDER OF THE RAINBOW GIRLS THE SUPREME ASSEMBLY',
#  'UNITED ASSOCIATION OF JOURNEYMEN & APPRENTICES OF THE PLUMBING & PIPE',
#  'WARRIOR BROTHERHOOD OF VETERANS MOTORCYCLE CLUB INC',
#  'CHC COMMUNITY CARE LLC',
#  'DEPARTMENT OF NEVADA VETERANS OF FOREIGN WARS OF THE US INC',
#  'RISK MANAGEMENT ASSOCIATES FLORIDA CHAPTER CORP',
#  'NATIONAL ASSOCIATION OF WATCH AND CLOCK COLLECTORS INC',
#  'HARMONY INC',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF COLORADO',
#  'AMERICAN-TURKISH ASSOCIATION OF SOUTHERN CALIFORNIA',
#  'NATIONAL ASSOCIATION OF COMPOSERS USA',
#  'HERITAGE ACADEMY INC',
#  'COUNTRY DANCE AND SONG SOCIETY INC',
#  'NATIONAL HUGUENOT SOCIETY',
#  'FATHER FLANAGANS BOYS HOME',
#  'VETERANS OF FOREIGN WARS OF THE US DEPT OF TEXAS AUXILIARY',
#  'FAMILY MOTOR COACH ASSOCIATION',
#  'FEDERATED GARDEN CLUBS OF MISSOURI INC',
#  'INTERNATIONAL ASSOCIATION OF FORENSIC NURSES',
#  'COUNTRY DANCE & SONG SOCIETY INC',
#  'RURITAN NATIONAL CORP',
#  'GUILDS OF THE SANTA FE OPERA INC',
#  'SOCIETY OF PLASTICS ENGINEERS',
#  'SOCIETY FOR MANAGEMENT INFORMATION SYSTEMS',
#  'JAMESTOWN SOCIETY',
#  'LEAGUE OF UNITED LATIN AMERICAN CITIZENS',
#  'TEAMSTER HORSEMEN MOTORCYCLE ASSOCIATION INC',
#  'PTA GEORGIA CONGRESS',
#  'MOST WORSHIPFUL PRINCE HALL GRAND LODGE OF FREE & ACCEPTED MASONS',
#  'SIGMA NU FRATERNITY',
#  'COLLEGE AND UNIVERSITY PROFESSIONAL ASSOCIATION FOR HUMAN SERVICES',
#  'SOLID WASTE ASSOCIATION OF NORTH AMERICA INC',
#  'INTERNATIONAL WOMENS INSOLVENCY & RESTRUCTURING CONFEDERATION INC',
#  'ARROW CHILD AND FAMILY MINISTRIES',
#  'ROYAL ORDER OF JESTERS',
#  'ACTS MINISTRY',
#  'ACTS MISSIONS',
#  'KAPPA ALPHA PSI FRATERNITY',
#  'SOCIETY OF MAYFLOWER DESCENDANTS IN THE STATE OF TEXAS',
#  'INTERNATIONAL CONGRESS OF CHURCHES AND MINISTRIES',
#  'PENN STATE ALUMNI ASSOCIATION',
#  'AMALGAMATED TRANSIT UNION',
#  '4-H CLUBS & AFFILIATED 4-H ORGANIZATIONS',
#  'TEXAS WATER UTILITIES ASSOCIATION',
#  'PARENTS FAMILIES AND FRIENDS OF LESBIANS AND GAYS INC',
#  'THE UNITED STATE PONY CLUBS INC',
#  'WESTERN GOVERNORS UNIVERSITY',
#  'AMERICAN ORFF-SCHULWERK ASSOCIATION',
#  'GAMMA PHI BETA SORORITY INC',
#  'AMATEUR ATHLETIC UNION OV THE UNITED STATES INC',
#  'DEPARTMENT OF OKLAHOMA LADIES AUXILIARY TO THE VFW INC',
#  'PILOT CLUB INTERNATIONAL',
#  'DELTA CHI NATIONAL HOUSING CORPORATION',
#  'SOROPTIMIST INTERNATIONAL TO THE AMERICAS INC',
#  'WOODMEN OF THE WORLD LIFE INSURANCE SOCIETY',
#  'COMMUNICATION ALLIANCE TO NETWORK THOROUGHBRED EX-RACEHORSES',
#  'BLUE STAR MOTHERS OF AMERICA INC',
#  'MUSIC TEACHERS NATIONAL ASSOCIATION',
#  'YOUNG CATHOLIC PROFESSIONALS',
#  'METHODIST RETIREMENT COMMUNITIES',
#  'PTA NEW MEXICO CONGRESS',
#  'UNITED MINE WORKERS OF AMERICA- INTERNATIONAL',
#  'TEXAS EXTENSION EDUCATION ASSOCIATION',
#  'VESTAVIA HILLS PARENT TEACHER ORGANIZATION INC',
#  'INTERNATIONAL ASSOCIATION OF ASSESSING OFFICERS',
#  'DEPARTMENT OF OREGON LADIES AUXILIARY TO THE VFW OF THE US',
#  'BAKERY CONFECTIONERY TOBACCO WORKERS AND GRAIN MILLERS INTL UNI',
#  'INTERNATIONAL READING ASSOCIATION INC',
#  'AMERICAN ROSE SOCIETY',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF LOUISIANA',
#  'SWEDISH WOMENS EDUCATIONAL ASSOCIATION',
#  'SAFARI CLUB INTERNATIONAL FOUNDATION',
#  'INTERNATIONAL ASSOCIATION OF EATING DISORDERS PROFESSIONALS FOUNDATI',
#  'NATIONAL ASSOCIATION OF NEGRO BUSINESS AND PROFESSIONAL WOMENS C',
#  'NATIONAL HOOK-UP OF BLACK WOMEN',
#  'BACK COUNTRY HORSEMEN OF AMERICA',
#  'ALASKA PTA',
#  'TEXAS STATE BRANCH 948 NATIONAL ASSOCIATION OF POSTAL SUPERVISORS',
#  'UTILITY WORKERS UNION OF AMERICA AFL-CIO',
#  'COMPUTER USING EDUCATORS',
#  'OMEGA PSI PHI FRATERNITY',
#  'LIFE STEPS FOUNDATION INC',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF KANSAS',
#  'ORDER OF THE EASTERN STAR OF MISSOURI GRAND CHAPTER',
#  'AMERICAN SOCIETY OF HEATING REFRIGERATING & A-C ENGINEERS',
#  'PHI DELTA KAPP INTERNATIONAL INC',
#  'FREE & ACCEPTED MASONS OF LOUISIANA GRAND LODGE',
#  'NATIONAL SORORITY OF PHI DELTA KAPPA INC',
#  'EPSILON PI TAU INC',
#  'TXCPSO INC',
#  'JEFFERSON CITY SENIOR HIGH SCHOOL PARENT TEACHERS ORGANIZATION',
#  'COMMEMORATIVE AIR FORCE',
#  'NATIONAL SOCIETY OF THE CHILDREN OF THE AMERICAN REVOLUTION',
#  'TENNESSEE MUSIC EDUCATION ASSOCIATION',
#  'ANCIENT FREE AND ACCEPTED MASONS OF OKLAHOMA',
#  'LOUISIANA 4-H FOUNDTION',
#  'AMATEUR ATHLETIC UNIONS OF THE US',
#  'STANDUP PARENTING INC',
#  'PUGET SOUND UNISERV COUNCIL',
#  'PI KAPPA ALPHA FRATERNITY',
#  'KIDS ENJOY EXERCISE NOW',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF OREGON',
#  'KNIGHTS OF PETER CLAVER',
#  'IDAHO CHAPLAINS CORPS INC',
#  'PTA IDAHO CONGRESS',
#  'INDUSTRIAL WORKERS OF THE WORLD',
#  'INTELLIGENT TRANSPORTATION SOCIETY OF AMERICA ITS AMERICA',
#  'AMERICAN COACH ASSOCIATION',
#  'INSTITUTE OF ELECTRICAL AND ELECTRONICS ENGINEERS',
#  'EXPERIMENTAL AIRCRAFT ASSOCIATION',
#  'SIGMA GAMMA RHO SORORITY INC',
#  'JUNIOR ROLLER DERBY ASSOCIATION',
#  'SUNRISE 2000 INC',
#  'GRAMBLING UNIVERSITY NATIONAL ALUMNI ASSOCIATION',
#  'PARAGON CHRISTIAN ALLIANCE INTERNATIONAL INC',
#  'OHIO STATE UNIVERSITY ALUMNI ASSOCIATION INC',
#  'VERITY HEALTH SYSTEM OF CALIFORNIA INC',
#  'INTERNATIONAL UNION OF PAINTERS AND ALLIED TRADES',
#  'TRAUMA INTERVENTION PROGRAMS INC',
#  'WESTERN DRESSAGE ASSOCIATION OF AMERICA',
#  'VFW AUXILIARY DEPARTMENT OF MISSOURI',
#  'FUTURE FARMERS OF AMERICA',
#  'HEALTH OCCUPATIONS STUDENTS OF AMERICA',
#  'SERTOMA INTERNATIONAL SPONSORSHIP FUND',
#  'THETA XI FRATERNITY',
#  'MINDS MATTER',
#  'PACIFIC COAST NORWEGIAN SINGERS ASSOCIATION',
#  'DAUGHTERS OF ISIS OF NORTH & SOUTH AMERICA',
#  'UNITED FOOD AND COMMERCIAL WORKERS INTERNATIONAL UNION',
#  'NATIONAL HUMAN RESOURCES ASSOCIATION INC',
#  'CALIFORNIA PILOTS ASSOCIATION',
#  'THE ARK OF TEXAS',
#  'INTERNATIONAL SOCIETY OF AUTOMATION',
#  'FEDERALLY EMPLOYED WOMEN INC',
#  'TRUSTEES OF DARTMOUTH COLLEGE',
#  'OREGON HIGH SCHOOL RODEO ASSOCIATION INC',
#  'REAL ESTATE STAGING ASSOCIATION INC',
#  'SUPREME TEMPLE PYTHIAN SISTERS',
#  'ACADEMY OF GENERAL DENTISTRY',
#  'NORTHWEST SWIM CIRCUIT',
#  'COLORADO COALITION FOR THE HOMELESS',
#  'FLORIDA NATIVE PLANT SOCIETY INC',
#  'GYRO INTERNATIONAL',
#  'ALLIANCE FOR RETIRED AMERICANS',
#  'ASSOCIATION OF SEWING AND DESIGN PROFESSIONALS INC',
#  'AMERICAN FISHERIES SOCIETY',
#  'WASHINGTON STATE UNIVERSITY 4-H CLUBS AND AFFILIATED 4-H ORGANIZAT',
#  'PHI SIGMA KAPPA',
#  'NATIONAL ENGINEERS WEEK FOUNDATION',
#  'ASSOCIATION OF PROPASAL MANAGEMENT PROFESSIONALS',
#  'NATIONAL SPEAKERS ASSOCIATION',
#  'ANCIENT FREE & ACCEPTED MASONS OF OREGON',
#  'NORTH AMERICAN BUTTERFLY ASSOCIATION INC',
#  'ROYAL ARCH MASONS OF KANSAS',
#  'STOA',
#  'CFIRE CHRISTIAN FUNDAMENTALIST INTERNAL REVENUE EMPLOYEES',
#  'UNITED BROTHERHOOD OF CARPENTERS & JOINERS OF AMERICA',
#  'LAMBDA ALPHA INTERNATIONAL',
#  'PTA TENNESSEE CONGRESS OF PARENTS TEACHERS INC',
#  'ORDER OF EASTERN STAR PRINCE HALL AFFILIATION OF LOUISIANA',
#  'FLORIDA EDUCATION ASSOCIATION',
#  'SMOCKING ARTS GUILD OF AMERICA INC',
#  'TEXAS ASSOCIATION OF SCHOOL BUINESS OFFICIALS',
#  'UNIVERSITY OF FLORIDA NATIONAL ALUMNI ASSOCIATION INC',
#  'PTA ARIZONA CONGRESS OF PARENTS AND TEACHERS INC',
#  'TEXAS SOCIETY OF PROFESSIONAL ENGINEERS',
#  'LIGHT FOR LIFE FOUNDATION INTERNATIONAL',
#  'NATIONAL BLACK NURSES ASSOCIATION INC',
#  'FREE & ACCEPTED MASONS OF ALABAMA',
#  'PTA WASHINGTON CONGRESS',
#  'NORTH AMERICAN FOLK MUSIC AND DANCE ALLIANCE INC',
#  'SIGMA THETA TAU INTERNATIONAL',
#  'PTA KANSAS CONGRESS OF PARENTS AND TEACHERS',
#  'ROYAL ARCH MASONS OF CALIFORNIA',
#  'ORDER OF THE FOUNDERS & PATRIOTS OF AMERICA',
#  'AMERCIAN LEGION',
#  'ORDER OF EASTERN STAR OF OKLAHOMA',
#  'HAMPTON UNIVERSITY',
#  'HILLEL THE FOUNDATION FOR JEWISH CAMPUS LIFE',
#  'GIRLS ON THE RUN INTERNATIONAL',
#  'ALLIANCE OF DIVINE LOVE INC',
#  'SOCIETY FOR MAINTENANCE AND RELIABILITY PROFESSIONALS FND',
#  'SOIL AND WATER CONSERVATION SOCIETY',
#  'ACADEMY OF MANAGED CARE PHARMACY',
#  'ANCIENT ORDER OF HIBERNIANS IN AMERICA',
#  'SOUTHERN EARLY CHILDHOOD ASSOC',
#  'GREYHOUND PETS OF AMERICA',
#  'DERMATOLOGY NURSES ASSOCIATION',
#  'AMERICAN GROUP PSYCHOTHERAPY ASSOCIATION INC',
#  'PHI DELTA KAPPA INTERNATIONAL INC',
#  'INSTITUTE OF REAL ESTATE MANAGEMENT OF THE NATL ASSN OF REALTORS',
#  'WASHINTON STATE UNIVERSITY',
#  'NATIONAL SOCIETY OF BLACK ENGINEERS',
#  'NATIONAL FELLOWSHIP OF RACEWAY MINISTRIES',
#  'FEDERATION OF TEXAS A&M UNIVERSITY MOTHERS CLUB',
#  'CLIPPED WINGS UNITED AIR LINES STEWARDESS ALUMNAE & FLIGHT ATTEND',
#  'CALIFORNIA ASSOCIATION FOR NURSE PRACTITIONERS',
#  'BMW CAR CLUB OF AMERICA INC',
#  'JOSHUA INC',
#  'ILLUMAN',
#  'AMERICAN ASSOCIATION OF ZOO KEEPERS',
#  'ASET-THE NEURODIAGNOSTIC SOCIETY',
#  'SAFARI CLUB INTERNATIONAL',
#  'LAMBDA CHI ALPHA FRATERNITY INC',
#  'CALIFORNIA PODIATRIC MEDICAL ASSOC',
#  'ALPHA KAPPA PSI FRATERNITY',
#  'BETA BETA BETA NATIONAL BIOLOGICAL HONOR SOCIETY',
#  'AMERICAN AGAPE FOUNDATION INC',
#  'UEMPOWERU INC',
#  'CORENET GLOBAL INC',
#  'APPA ASSOCIATION OF HIGHER EDUCATION FACILITIES OFFICERS',
#  'ENTREPRENEURS ORGANIZATION',
#  'CENTER FOR THE STUDY OF CLASSICAL ARCHITECTURE INC',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF TENNESSEE',
#  'AMERICAN MARKETING ASSOCIATION INC',
#  'UNITED STATES BOWLING CONGRESS',
#  'IOTA PHI LAMBDA SORORITY INC',
#  'DANCE INITIATIVE INC',
#  'NATIONAL SOCIETY OF TOLE AND DECORATIVE PAINTERS INC',
#  'UNITED TRANSPORTATION UNION',
#  'INTERNATIONAL ALLIANCE THEATRICAL STAGE EMPLOYEES',
#  'IRON PIGS MOTORCYCLE CLUB',
#  'EXECUTIVE WOMENS GOLF ASSOCIATION',
#  'HEARING LOSS ASSOCIATION OF AMERICA',
#  'NATIONAL ALUMNAE ASSOC OF SPELMAN COLLEGE',
#  'BLACKS IN GOVERNMENT',
#  'ASSOCIATION OF TRADITIONAL HOOKING ARTIST',
#  'AMERICAN RESEARCH CENTER IN EGYPT',
#  'PARENTS HELPING PARENTS INC',
#  'NATIONAL COUNCIL OF THE UNITED STATES SOCIETY OF ST VNCNT DE PAUL',
#  'DEPRESSION AND BIPOLAR SUPPORT ALLIANCE',
#  'HOLIDAY RAMBLER RECREATIONAL',
#  'AMERICAN CANCER SOCIETY INC',
#  'FOLDS OF HONOR FOUNDATION',
#  'ANCHORAGE COMMUNITY MENTAL HEALTH SERVICES',
#  'PRAISE CHAPEL CHRISTIAN FELLOWSHIP CHURCHES & MINISTRIES INTL',
#  'DEPARTMENT OF NEVADA VETERANS OF FOREIGH WARS OF THE U S INC',
#  'ALPHA DELTA KAPPA SORORITY INC',
#  'IMPROVED ORDER OF RED MEN OF TEXAS',
#  'FRIENDS OF THE PARK',
#  'DAUGHTERS OF THE REPUBLIC OF TX INC',
#  'AMERICAN TRAIN DISPATCHERS ASSOCIATION',
#  'MEA-MFT',
#  'SOUTHWEST DISTRICT KIWANIS FOUNDATION',
#  'PTA COLORADO CONGRESS',
#  'CHARTER ROAD PRODUCTIONS INCORPORATED',
#  'GRAND LODGE OF MISSISSIPPI FREE AND ACCEPTED MASONS',
#  'GRAND LODGE OF MISSISSIPPI FREE & ACCEPTED MASONS',
#  'FREE & ACCEPTED MASONS OF MISSISSIPPI',
#  'ORDER OF THE ALHAMBRA',
#  'ARC OF ARIZONA INC',
#  'INTERNATIONAL FEDERATION OF PROFESSIONAL & TECHNICAL ENGINEERS',
#  'DELTA TAU DELTA FRATERNITY',
#  'STATE CHARTERED CREDIT UNIONS IN FLORIDA',
#  'VFW AUXILIARY DEPARTMENT OF OKLAHOMA',
#  'KAPPA BETA GAMMA INTERNATIONAL INC',
#  'OREGON STATE GRANGE PATRONS OF HUSBANDRY',
#  'AMERICAN RHODODENDRON SOCIETY',
#  'INTERNATIONAL COSTUMERS GUILD INC',
#  'ASSOC FOR EDUCATION & REHBLTATN OF THE BLIND & VISUALLY IMPAIRED',
#  'IZAAK WALTON LEAGUE OF AMERICA INC',
#  'NATIONAL SOCIETY OF THE SONS OF UTAH PIONEERS',
#  'COMMUNITY NETWORK AFRICAN AMERICAN TELECOMMUNICATION PROFESSIONALS OF',
#  'LEAGUE OF WOMEN VOTERS OF FLORIDA',
#  'COUNCIL OF ALBUQUERQUE GARDEN CLUBS',
#  'ALLIANCE OF THE FRIENDS OF THE DEKALB COUNTY LIBRARY',
#  'FULL GOSPEL ASSEMBLIES OF AMERICA INC',
#  'UNITED SPINAL ASSOCIATION INC',
#  'SOCIETY OF CRITICAL CARE MEDICINE',
#  'UTAH EDUCATION ASSOCIATION',
#  'CAMP FIRE',
#  'ZETA BETA TAU FRATERNITY',
#  'AMERICAN HARP SOCIETY',
#  'COMBAT VETERANS MOTORCYCLE ASSOCIATION',
#  'NATIONAL UTILITY CONTRACTORS ASSOCIATION INC',
#  'LABORERS INTERNATIONAL UNION OF NORTH AMERICA',
#  'LABOR AND EMPLOYMENT RELATIONS ASSOCIATION',
#  'PTSA WASHINGTON CONGRESS',
#  'CORNERSTONE CHRISTIAN MINISTRIES',
#  'AMERICANS UNITED FOR SEPARATION OF CHURCH & STATE',
#  'M W PRINCE HALL GRAND LODGE FREE AND ACCEPTED MASONS OF LOUISIAN',
#  'BIRTH NETWORK',
#  'APPA-ASSOCIATION OF HIGHER EDUCATION FACILITIES OFFICERS',
#  'BENEVOLENT AND PROTECTIVE ORDER OF ELKS OF THE USA',
#  'ALPHA GAMMA RHO FRATERNITY',
#  'BENEVOLENT & PROTECTIVE ORDER OF ELKS OF THE USA',
#  'SHERIFFS COMMUNITY ORGANIZED POLICING EFFORTS',
#  'TRANSPORT WORKERS UNION OF AMERICA',
#  'SOCIETY FOR HUMAN RESOURCE MANAGEMENT',
#  'COALITION OF LABOR UNION WOMEN CLUB',
#  'NATIONAL PONY EXPRESS ASSOCIATION',
#  'SERTOMA FOUNDATION',
#  'VOITURE NATIONALE LA SOCIETE DES 40 HOMMES ET 8 CHEVAUX',
#  'STARS INC',
#  'PTA MISSOURI CONGRESS',
#  'KAPPA SIGMA FRATERNITY',
#  'ALPHA TAU OMEGA FRATERNITY',
#  'OMICRON KAPPA UPSILON HONORARY DENTAL SOCIETY',
#  'SOCIETY FOR THE PRESERVATION AND ENCOURAGEMENT OF BARBERSHOP',
#  'THE ARC OF TEXAS',
#  'FAR EASTERN UNIVERSITY NURSING ALUMNI FOUNDATION INC',
#  'SIGMA GAMMA RHO SOROITY INC',
#  'NATIONAL SOCIETY UNITED STATES DAUGHTERS OF 1812',
#  'UNITED STATES PONY CLUB INC',
#  'PEACEWORKS -- DANCES OF UNIVERSAL PEACE NORTH AMERICA',
#  'CALIFORNIA RETIRED TEACHERS ASSOCIATION',
#  'INTERNATIONAL ASSOCIATION OF EATING DISORDERS PROFESSIONALS FOUNDATION',
#  'IDAHO ASSOCIATION FOR THE EDUCATION OF YOUNG CHILDREN',
#  'VETERANS OF FOREIGN WARS DEPARTMENT OF NEW MEXICO OF THE U S',
#  'LEAGUE OF UNITED LATIN AMERICA CITIZENS',
#  'PARENTS WITHOUT PARTNERS INC',
#  'WICHITA INDEPENDENT NEIGHBORHOODS INC',
#  'FLORIDA ASSOCIATION OF ENVIROMENTAL PROFESSIONALS INC',
#  'MANKIND PROJECT',
#  'PTA CALIFORNIA CONGRESS OF PARENTS TEACHERS AND STUDENTS INC',
#  'AMERICAN CRIMINAL JUSTICE ASSOCIATION LAMBDA ALPHA EPSILON',
#  'ELDERLY HOUSING DEVELOPMENT AND OPERATIONS CORPORATION',
#  'NATIONAL DENTAL ASSOCIATION INC',
#  'PHYSICIANS FOR SOCIAL RESPONSIBILITY INC',
#  'JOBS DAUGHTERS INTERNATIONAL',
#  'PLANNED PARENTHOOD AFFILIATES OF CALIFORNIA INC',
#  'TOOLBANK USA INC',
#  'SOROPTIMIST INTERNATIONAL OF THE AMERICAS',
#  'ASSOCIATION FOR CONFLICT RESOLUTION',
#  'TRANSPORTATION ENERGY PARTNERSHIP',
#  'UNITED WORKERS',
#  'WASHINGTON STATE UNIVERSITY 4-H CLUBS AND AFFILIATED ORGANIZATIONS',
#  'AMERICAN COLLEGE OF PHYSICIANS',
#  'NATIONAL ASSOCIATION OF POSTAL SUPERVISORS',
#  'HELPING YOUNG PEOPLE EXCEL INC',
#  'ORDER OF QUETZALCOATL PLUMED SERPENT',
#  'SAN BENITO YOUTH SOCCER LEAGUE',
#  'JOBS WITH JUSTICE EDUCATION FUND',
#  'SIGMA THETA TAU INC',
#  'DAUGHTERS OF UNION VETERANS OF THE CIVIL WAR 1861 1865',
#  'NATIONAL SOCIETY COLONIAL DAMES XVII CENTURY',
#  'GARDENERS OF AMERICA INC',
#  'YELLOWSTONE COUNTY 4-H COUNCIL',
#  'NATIONAL ASSOCIATON OF CORPORATE DIRECTORS',
#  'EARLY CHILDHOOD MUSIC ASSOCIATION',
#  'SAN RAMON VALLEY EDUCATIONAL FOUNDATION',
#  'CHI EPSILON',
#  'HOUSE OF HEROES INC',
#  'LINKS INC',
#  'SERRA INTERNATIONAL',
#  'CATHOLIC ENGAGED ENCOUNTER INC',
#  'ANCIENT FREE & ACCEPTED MASONS OF COLORADO',
#  'NATIONAL GERONTOLOGICAL NURSING ASSOCIATION INC',
#  'RETROUVAILLE INTERNATIONAL INC',
#  'SIGMA PI FRATERNITY INTERNATIONAL INC',
#  'KLEIN SUPPORT GROUP INC',
#  'ASSOCIATION OF WOMEN IN THE METAL INDUSTRIES INC',
#  'SISTERS NETWORK',
#  'LAFAYETTE GARDEN CLUB',
#  'VETERANS OF FOREIGN WARS DEPARTMENT OF ARKANSAS',
#  'HOOSIER CARE INC',
#  'SEOUL NATIONAL UNIVERSITY ALUMNI',
#  'AMERICAN HUMANIST ASSOCIATION',
#  'CALIFORNIA STATE CARE PROVIDERS ASSOCIATION',
#  'SOCIETY OF AMERICAN MILITARY ENGINEERS',
#  'WASHINGTON EXPLORER SEARCH AND RESCUE',
#  'TEXAS MASTER GARNENER ASSOCIATION INC',
#  'ROAL',
#  'AGENTS ASSOCIATION',
#  'HISPANIC DENTAL ASSOCIATION',
#  'BROTHERHOOD OF RAILROAD SIGNALMEN',
#  'AMERICAN LEGION POST',
#  'ASSOCIATION OF EVANGELICAL GOSPEL ASSEMBLIES',
#  'PTA LOUISIANA CONGRESS',
#  'NORTHERN PLAINS RESOURCE COUNCIL',
#  'HEALTHCARE INFORMATION AND MANAGEMENT SYSTEMS SOCIETY',
#  'TEXAS ASSOCIATION OF SCHOOL BUSINESS OFFICIALS',
#  'KAPPA ALPHA PSI FRATERNITY INC',
#  'CAMP QUEST INC',
#  'WOMEN IN AVIATION',
#  'IMMIGRANT HOPE',
#  'ROYAL ARCH MASONS OF TENNESSEE',
#  'NATIONAL AUTISM ASSOCIATION INC',
#  'ACTIVE 20-30 UNITED STATES AND CANADA',
#  'FOUR LETTER WORD INC',
#  'SOUTHEAST SECTION OF THE NINETY NINES INC',
#  'PAN AMERICAN ROUND TABLE OF TEXAS',
#  'AMERICAN BUSINESS WOMENS ASSOCIATION',
#  'PILOT INTERNATIONAL INC',
#  'OASIS INSTITUTE',
#  'ASSOCIATION OF GOVERNMENT ACCOUNTANTS',
#  'UNITED COMMERCIAL TRAVELERS OF AMERICA',
#  'INTERNATIONAL CAPOEIRA ANGOLA FOUNDATION',
#  'ORDER OF THE AMARANTH INC SUPREME COUNCIL',
#  'LITTLE MISS KICKBALL INTERNATIONAL INC',
#  'CONSTRUCTION FINANCIAL MANAGEMENT ASSOCIATION',
#  'AMERICAN ART THERAPY ASSOCIATION',
#  'FEDERATION OF FLY FISHERS',
#  'SIGMA CHI FRATERNITY',
#  'SI ON',
#  'U M ARMY',
#  'KOREAN WAR VETERANS ASSOCIATION INC',
#  'HOLIDAY RAMBLER RECREATIONAL VEHICLE CLUB',
#  'PARENT BOOSTERS USA INC',
#  'NATIONAL JUNIOR COLLEGE ATHLETIC ASSOCIATION',
#  'GRAND CHAPTER OF TENNESSEE ORDER OF THE EASTERN STAR',
#  'MISSOURI INTERACTIVE TELECOMMUNICATIONS EDUCATION',
#  'WOMEN MARINES ASSOCIATION',
#  'JUMPSTART COALITION FOR PERSONAL FINANCIAL LITERACY',
#  'WEBSTER GROVES SCHOOL DISTRICT PARENT-TEACHERS ORGANIZATION',
#  'AMERICAN BEGONIA SOCIETY',
#  'OMICRON KAPPA UPSILON-HONORARY DENTAL SOCIETY',
#  'AMERICAN COLLEGE OF PHYSICIANS SERVICES',
#  'MILITARY ORDER OF THE COOTIE OF THE UNITED STATES',
#  'NATIONAL AMBUCS INC',
#  'CONFRERIE DE-LA-CHAINE DES ROTISSEURS LTD',
#  'AMERICAN FEDERATION OF TEACHERS',
#  'PEOPLE TO PEOPLE INTERNATIONAL',
#  'REACT INTERNATIONAL',
#  'SOCIETY OF FIRE PROTECTION ENGINEERS',
#  'VETERANS OF FOREIGN WARS OF THE UNITED STATES DEPT OF TEXAS',
#  'AMERICAN ASSOCIATION OF FAMILY AND CONSUMER SCIENCES',
#  'LOUISIANA GARDEN CLUB FEDERATION INC',
#  'SERB NATIONAL FEDERATION',
#  'DAUGHTERS OF NORWAY',
#  'ANCIENT FREE & ACCEPTED MASON OF KANSAS',
#  'INTERNATIONAL ALLIANCE THEATRICAL STAGE EMPLOYEES & MOVING PICTURE',
#  'ROYAL AND SELECT MASTERS OF GEORGIA',
#  'UNITED STATES MASTERS SWIMMING INC',
#  'ANCIENT EGYPTIAN ARABIC ORDER NOBLES MYSTIC SHRINE OF N & S AMER',
#  'ASPENPOINTE INC',
#  'VETERANS OF FOREIGH WARS OF THE UNITED STATES DEPT OF COLORADO',
#  'ETA PHI BETA SORORITY INC',
#  'POINT MAN INTERNATIONAL MINISTRIES',
#  'MULTI COMMUNITY DIVERSIFIED SERVICES INC',
#  'VETERANS OF FOREIGN WARS AUXILIARY',
#  'ARTS SCIENCE AND TECHNOLOGY EDUCATIONAL CORPORATION OF TEHACHA',
#  'UPTE-CWA RETIRED MEMBERS CHAPTER 9119',
#  'WORLD PRESIDENTS ORGANIZATION INC',
#  'HOMELESS ANIMAL RESCUE TEAM',
#  'DREAM WEAVER CHARITABLE TR',
#  'FLORIDA ASSOCIATION FOR THE EDUCATION OF YOUNG CHILDREN',
#  'MOTHERS HELPERS INC',
#  'HALLMARK COUNCIL NO 3 ROYAL AND SELECT MASTERS',
#  'MANNAS HANA RIDING CENTER',
#  'SOUTHERN OREGON CHAPTER OF ROBERT MORRIS ASSOCIATES GROUP',
#  'COMMUNITY ACTION GROUP',
#  'GILA MIMBRES COMMUNITY RADIO',
#  'KIWANIS CLUB OF DUNWOODY YOUNG PROFESSIONALS INC',
#  'SOCIETY OF ST VINCENT DE PAUL ST PATRICK CONFERENCE',
#  'PERRY AREA COMMUNITY TR',
#  'ASSOCIATION TO AID UNESCO PROGRAM IMPLEMENTATION',
#  'HERE FOR KIDS INTERNATIONAL',
#  'MYSTIC ORDER OF VEILED PROPHETS OF ENCHANTED REALM',
#  'INTERNATIONAL ASSOCIATION OF DUNCAN CERTIFIED CERAMIC TEACHERS',
#  'UNITED BROTHERS AND SISTERS OF SIERRA LEONE',
#  'CREATIVE ENTERPRISES FOUNDATION INC',
#  'HEARTBEAT FOSTER FAMILY SUPPORT',
#  'OPERATION PEACE INC',
#  'ANIMAL LIFE LINE',
#  'AMERICAN HOUSING PRESERVATION CORPORATION',
#  'NORTH WEST YOUTH POWER INC',
#  'CENTER FOR BRAIN INJURY EDUCATION INC',
#  'AMERICAN UNION RELIEF SOCIETY',
#  'ST PAULS BUILDING ON FAITH FUND INC',
#  'HOLIDAY RAMBLER RV CLUB',
#  'EARTH ETHICS INC',
#  'DRIVING RURAL YAKIMA VALLEYS ECONOMY',
#  'CHOOSE LIFE MINISTRIES INC',
#  'EMPOWERMENT 21',
#  'THOMASVILLE ENTERTAINMENT FOUNDATION ENDOWMENT TR',
#  'WESTFIELD SCHOLARSHIP CHARITABLE TR',
#  'HMONG AMERICAN COMMUNITY OF OREGON LLC',
#  'GUT CHECK CLOSTRIDIUM SEPTICUM FOUNDATION',
#  'HAVING A NEW DEVELOPMENT',
#  'WORLD ORGANIZATION',
#  'NORTH ARKANSAS SENIOR HOUSING OF BULL SHOALS AND GRAVETTE INC',
#  'CUPCAKES & CLUTTERBUGS INC',
#  'PYPTW INC',
#  'MARION COUNTY DOMESTIC VIOLENCE TASK FORCE',
#  'VETERANS OF FOREIGN WARS POST 3830',
#  'ALL POSITIVES POSSIBLE',
#  'LADIES AUXILIARY TO THE VFW DISTRICT 6',
#  'EVERY FAMILY NEEDS A VOICE',
#  'CITIZENS FOR MIDWIFERY',
#  'K-TOWN SOUND SHOW',
#  'PARADIGM FLUX INC',
#  'LIBERTY PARENT TEACHER COMMITEE',
#  'WAYNE COUNTY PROTECTIVE AGENCY INC',
#  'CENTRO CULTURAL OAXACA INC',
#  'LEE ANGELICH MEMORIAL SCHOLARSHIPS',
#  'OROVILLE HIGH SCHOOL SCHOLARSHIP FUND',
#  'MISSOURI YOUTH RUGBY',
#  'GREATER AUGUSTA HBCU ALUMNI ALLIANCE INC',
#  'ALABAMA RIVER REGION BALLET SCHOOL AND YOUTH COMPANY',
#  'SENIOR CITIZENS RETIREES CONTINENTAL RANCH',
#  'GEORGIA FAMILY ASSOCIATION INC',
#  'SUNSHINE AND RAINBOWS EARLY LEARNING CENTER',
#  'IGLESIA PENTECOSTES JARDIN DE LA PROFECIA',
#  'ARKANSAS DEPARTMENT OF CORRECTION CENTAL OFFICE EMPLOYEE ASSOCIATION',
#  'SOUTH PARK HERITAGE ASSOCIATION INC',
#  'WASHINGTON ARTILLERY CAMP 2178',
#  'SOUTHERN BAPTIST HOSPITAL OF FLORI DA INC',
#  'CAMP BURGE YOUTH AND ADOLESCENT DEVELOPMENT FOUNDATION',
#  'SEATTLE JEWISH GIRLS HIGH SCHOOL',
#  'OAK GROVE ELEMENTARY SCHOOL PARENT- TEACHER ORG OF FAYETTE COUNTY INC',
#  'YOUNG ADULT MINISTRY OF DAYTONA INC',
#  'RONALD WILSON REAGAN ACADEMY',
#  'SHILOH BIBLE COLLEGE INC',
#  'RUNNERS BOOSTER CLUB',
#  'BINMALEY CATHOLIC HIGH SCHOOL ALUMNI ASSOCIATION-USA',
#  'GEORGIA PARTNERSHIP FOR EXCELLENCE IN EDUCATION INC',
#  'OREGON AND S IDAHO LABORERS EMPLOYERS COOPERATION AND EDU TR',
#  'INDEPENDENCE PATRIOTS BASEBALL GROUP',
#  'NORTH EAST KANSAS SEARCH AND RESCUE ASSOCIATION',
#  'THE ALFRED AND ADELE DAVIS ACADEMY INC',
#  'NATIONAL HOOKUP OF BLACK WOMEN',
#  'V-TOWN DERBY DAMES',
#  'AMERICAN CATHOLIC CHURCH ARTWALK',
#  'MONTGOMERY AREA NONTRADITIONAL EQUESTRIANS INC',
#  'CPL JACOB C LEICHT MEMORIAL AMVETS POST 1000',
#  'YOUTH BASEBALL BOOSTERS OF FRIENDSWOOD',
#  'BRYTE AND BRODERICK COMMUNITY ACTION NETWORK INC',
#  'RANCH GOOD DAYS INC',
#  'TRIPLE THREAT SPORTS AND ENTERTAINMENT INC',
#  'HEAVENLY HANDS MINISTRY INC',
#  'SAN BENITO COUNTY AMATEUR RADIO ASSOCIATION SBCARA',
#  'LITTLE ELEPHANT INC',
#  'HOUSE OF PRAYER FOR EVERYONE INTERNATIONAL INC',
#  'ELLIS CARE',
#  'CAMP VILLERE SPORTSMENS CLUB',
#  'EBONY INN INC',
#  'SNOQUALMIE EDUCATION ASSOCIATION',
#  'JOHNE STEINBECK PARENT TEACHER ORGANIZATION INC',
#  'LIVING WORLD ALLIANCE INC',
#  'UNITED METHODIST VOLUNTEERS IN MISSION',
#  'DREAMOR RANCH NON PROFIT CORPORATION',
#  'HAWAII-NIIGATA INC',
#  'EXALTING JESUS INC',
#  'PRAYERFUL PUBLISHING INC',
#  'MEADOWS ARTS AND TECHNOLOGY ELEMENTARY SCHOOL',
#  'FREE AND ACCEPTED MASONS OF GEORGIA TENNILLE LODGE',
#  'INNER WHEEL USA INC',
#  'METRO ATLANTA HOCKEY ASSOCIATION',
#  'FAMILY RESOURCE CENTER OF TRUCKEE',
#  'ASSOCIATION FOR COMMUNITY ENHANCEMENT',
#  'CLEARWATER CHAPTER AMERICAN GUILD OF ORGANISTS',
#  'PIPING INDUSTRY PROGRAM TRUST OF LOCAL 624',
#  'HILLSBOROUGH COUNTY MEDICAL ASSOCIATION INC',
#  'COMPASS ROSE FOUNDATION INC',
#  'JACQUELINE L PRICE MINISTRIES',
#  'POLICE BENEVOLENT ASSO OF HOLLYWOOD',
#  'INTERFRATERNITY COUNCIL INC',
#  'GEORGIA MUTUAL AID GROUP',
#  'GEORGIA YOUTH SCIENCE & TECHNOLOGY CENTER INC',
#  'ARTHUR R LANNI MEMORIAL AMERICAN LEGION POST 365',
#  'AMERICAN FEDERATIONOF GOVERNMENT EMPLOYEES',
#  'THE GAMMA ALPHA CHAPTER OF ZETA PHI BETA SORORITY INC',
#  'AMERICAN STRING TEACHERS ASSOCIATION INCORPORATED',
#  'NATIONAL ASSOCIATION LETTER CARRIERS 3344 JACKSONVILLE AL',
#  'ARTHUR SAWYER POST NO 28 THE AMERICAN LEGION INCORPORATED',
#  'BLOUNTSTOWN ROTARY CLUB INC',
#  'APPALACHIAN BLACK BEAR REHABILITATION AND RELEASE CENTER',
#  'AMERICAN ASSOC OF UNIVERSITY WOMEN',
#  'THE FLORIDA BAR FOUNDATION ENDOWMENT TRUST',
#  'LIGHTHOUSE LYMPHEDEMA SUPPORT GROUP',
#  'AUTOMOTIVE INDUSTRY EDUCATION TR',
#  'WILES FAM CHARITABLE TR',
#  'FLORIDA FIREFIGHTERS CHARITIES TR',
#  'ASSOCIATION OF PROFESSIONAL AND TECHNICAL ADMINISTRATORS',
#  'FRIENDS OF THE LEE COUNTY LIBRARY',
#  'CAMP JEWEL',
#  'UNITED TRANSPORTATION SECURITY PROFESSIONALS OF AMERICA',
#  'OREGON ASSOCIATION OF PROFESSIONAL ENERGY MANAGERS',
#  'OCONEE PREVENTION RESOURCE COUNCIL INC',
#  'TRANSFORMED LIFE CHRISTIAN MINISTRIES',
#  'THE HISTORICAL SOCIETY OF UNITED STATES DISTRICT COURT FOR THE',
#  'TORCHBEARERS FOUNDATION',
#  'TAYLOR MADE HOMES SERVICES',
#  'TRANSFORMATIVE LANGUAGE ARTS NETWORK',
#  'EKD COMMUNITY OPPORTUNITY CENTER INC',
#  'SANTIAM MENS CLUB',
#  'SOCAL ANIMAL RESPONSE TEAM',
#  'FOSTERING MEMORIES',
#  'VOICES OF INLAND COMMUNITIES FOR EDUCATION HEALTH AND SAFETY',
#  'ONEIRO INC',
#  'DOBBINS MIDDLE SCHOOL PTSA INC',
#  'XERODERMA PIGMENTOSUM FAMILY SUPPORT GROUP',
#  'YUMA AUXILARY COMMUNICATIONS SERVICE',
#  'EXPERIMENTAL AIRCRAFT ASSOCIATION ROCKY MOUNTAIN CHAPTER 301 INC',
#  'CHISHOLM YOUTH DEVELOPMENT',
#  'ALL FOR THE INCREDIBLE KIDS INC',
#  'WOODLAND RIDGE SENIOR LIVING INC',
#  'TOP ROCK TOP 3 ASSOCIATION',
#  'CRESTON ACTIVITIES TOWN CENTER HELPING HAND',
#  'COFFEE FOR CHRIST',
#  'ASSOCIATION OF GUINEANS IN ATLANTA INC',
#  'GUM CREEK CEMETERY TR',
#  'ATKINS FAM CEMETERY TR',
#  'SEDALIA CHORALE ASSOCIATION INC',
#  'FLINT ELECTRIC MEMBERSHIP CORPORATION VEBA TR',
#  'MARCELLA CENTER FOR THE ARTS AND EDUCATION',
#  'UNIVERSITY OF SOUTH FLORIDA FOUNDATION INC',
#  'JOHN F KENNEDY PARENT TEACHER ASSOCIATION',
#  'YOUNG AMBASSADORS INC',
#  'THE UNITY AND HOPE CENTER',
#  'NORTH TEXAS LEADERS AND EXECUTIVES ADVOCATING DIVERSITY',
#  'HOT FLASHZ INC',
#  'BACK TO NATIVES RESTORATION',
#  'MOTHER ATTORNEYS MENTORING ASSOCIATION OF SEATTLE',
#  'REIAC EAST INC',
#  'AMERICAN ACADEMY OF PEDIATRICS CALIFORNIA DISTRICT',
#  'AMERICAN ASSOCIATION OF ADAPTED SPORTS PROGRAMS INC',
#  'THE HEALING PLACE OF ATHENS INC',
#  'JACKSON COUNTY ARES-RACES AMATEUR RADIO EMERGENCY SERVICE-RADIO',
#  'GARDENING FRIENDS OF THE BIG BEND INC',
#  'ART SANDY SPRINGS INC',
#  'WILLOW GLEN HIGH SCHOOL PARENT CLUB',
#  'SONOMA VALLEY DOG OWNERS AND GUARDIANS',
#  'HOME EDUCATION AFTER RIGHTEOUS TEACHING INC',
#  'LADYLIKE FOUNDATION',
#  'FRIENDS OF RED CLAY STATE PARK',
#  'COMMUNITY ENRICHMENT CENTER NAVARRE',
#  'DELRAY COMMUNITY SERVICES INC',
#  'LAKELAND SAINTS INC',
#  'PHYSICIAN AND UNDERGRADUATE STUDENT EDUCATIONAL PARTNERSHIPS FOUNDATIO',
#  'LAKE OF THE OZARKS WATERSHED ALLIANCE',
#  'MWI VETERINARY SUPPLY INC GROUP INSURANCE FUND',
#  'ANDRAGATHIA INC',
#  'BAY AREA PARAGLIDING ASSOCIATION',
#  'SOUTH CENTRAL CONFERENCE ASSOCIATION OF KY INC',
#  'ZOO FOUNDATION INC',
#  'CARRIERS OF THE CONSCIOUSNESS OF WHOLENESS INC',
#  'HOMELESS ANIMAL VOLUNTEER NETWORK OF CHOCTAW COUNTY',
#  'HEALTHCARE INOFRMATION AND MANAGEMENT SYSTEMS SOCIETY',
#  'TARPON SPRINGS HOSPITAL FOUNDATION INC',
#  'CENTER FOR EQUITY AND ADEQUACY IN PUBLIC SCHOOL FINANCE INC',
#  'OCEANSIDE NORTH SAN DIEGO COUNTY CALIFORNIA PTO',
#  '4 LEGGED RESCUE',
#  'EMORY UNIVERSITY',
#  'HAWAII CRB CHAPTER',
#  'WOMEN IN TECHNOLOGY OF TENNESSEE',
#  'EVERGREEN CHAPTER AMCA INC',
#  'CAMP IDA CHRISTIAN YOUTH ENCAMPMENT',
#  'NONPROFIT TECHNICAL ASSISTANCE CENTER',
#  'COLORADO CRIME SURVIVORS NETWORK INC',
#  'EXPERIMENTAL SOUNDING ROCKET ASSOCIATION',
#  'JUSTICE UNITY GENEROSITY SERVICE INC',
#  'FIRST DISTRICT LADIES AUXILIARY TO THE VETERANS OF FOREIGN WARS DEPT',
#  'CRAIG COUNTY COMMUNITY IMPROVEMENT ASSOCIATION',
#  'GLOBAL CONSERCATION INSTITUTE-REV PROC 2014-11 STL RETRO REINSTATEM',
#  'TWINKLE LITTLE STARS INC INTERNATIONAL SOARING EAGLES',
#  'SEATTLE AREA ROWING ASSOCIATION',
#  'ARKANSAS HIGHWAY POLICE CHARITY FUND',
#  'ONE MORE CHANCE',
#  'URBAN MANAGEMENT ASSISTANTS OF CENTRAL TEXAS',
#  '2ND 2 NONE B TRAINING',
#  'STEP UP MENTORING PROGRAM',
#  'SATURATION CHURCH PLANTING INTERNATIONAL INC',
#  'OGILVIE FAMILY MINISTRIES INC',
#  'GAMMA IOTA CHAPTER OF ALPHA DELTA PI HOUSE CORPORATION',
#  'PINELLAS COUNTY MEDICAL SOCIETY INC',
#  'MAISON DESPRIT OF LAFAYETTE INC',
#  'CHRISTIAN FAMILY COOPERATIVE INC',
#  'K4C MINISTRIES INC',
#  'MEMORY INC',
#  'GOSPEL TRUTH MINISTRIES OF JESUS CHRIST INC',
#  'BIRMINGHAM CHAPTER OF THE AMERICAN ASSOCIATION OF BLACKS IN ENERGY',
#  'BLOUNT COUNTY FOSTER PARENT ASSOCIATION',
#  'EAST MONTGOMERY ELEMENTARY PTO',
#  'P C S CO INC',
#  'TENNESSEE DEAF-BLIND ASSOCIATION',
#  'MU THETA CHAPTER OF ZETA PHI BETA SORORITY INC',
#  'MOUNTAIN EMPIRE TENNIS ASSOCIATION',
#  'VERITAS MINISTRIES INC',
#  'TENNESSEE ASSOCIATION FOR BEHAVIOR ANALYSIS',
#  'SUPPORT AND TRAINING FOR EXCEPTIONAL PARENTS INC',
#  'HIGH PRAISES BAPTIST CHURCH',
#  'AFRICAN AMERICAN MUTUAL SUPPORT ASSOCIATES INC',
#  'AMERICAN BUSINESS WOMENS ASSN AIRPORT CHARTER CHAPTER',
#  'LANIER HEALTH SERVICES INC',
#  'JACKSONVILLE ELECTRICAL JOINT APPRENTICESHIP AND TRNG COMM INC',
#  'REACHING THE WORLD MINISTRIES',
#  'PPS & FOCUS GROUP MINISTRIES INC',
#  'CENTRAL ARKANSAS CHAPTER OF THE ASSOCIATION OF LEGAL ADMINISTRATOR',
#  'KNOXVILLE AREA DISTRICTS AL-ANON INC',
#  'THE VILLAGE CULTURAL ARTS CENTER INC',
#  'PEOPLE FOR ANIMAL WELFARE SOCIETY INC',
#  'GENERAL FEDERATED WOMENS CLUB TELLICO VILLAGE',
#  'ROPHEKA ROCK OF THE WORLD MINISTRIES INC',
#  'DIV NO 1 LADIES ANCIENT ORDER OF HIBERNIANS INC OF CHATHAM COUNTY',
#  'WHATEVER IT TAKES TO GET BACK INTO THE COMMUNITY',
#  'SOUTHERN FOUNDATION FOR HOMELESS',
#  'MISSISSIPPI ORGAN RECOVERY AGENCY',
#  'AUGUSTA FLYERS TRACK CLUB INC',
#  'COMUNIDAD PARA BAJA CALIFORNIA',
#  'PROMOTIONAL PRODUCTS ASSOCIATION OF THE MID-SOUTH',
#  'AIR FORCE VILLAGES INC',
#  'GEORGIA RESIDENTIAL AND COMMUNITY HEALTH CARE INC',
#  'MIDSOUTH AQUATIC PLANT MANAGEMENT SOCIETY INC',
#  'FRIENDS OF TENNESSEES BABIES WITH SPECIAL NEEDS',
#  'ISA-THE INSTRUMENTATION SYSTEMS AND AUTOMATION SOCIETY',
#  'WESLEY AT MILAN INC',
#  'EAST TENNESSEE BIOMEDICAL ASSOCIATION',
#  'TAMAR MINISTRIES',
#  'BENTON COUNTY SPORTSMAN ASSOCIATION INC',
#  'GUIDANCE ACADEMY OF TRUE ENRICHMENT',
#  'SOUTH AMERICAN TOUCH INC',
#  'CLARSVILLE VOLUNTEER HEALTH INC',
#  'LTW GLOBAL INITIATIVES INC',
#  'SOUTHERN ALLIANCE FOUNDATION FOR PEOPLE & ANIMAL WELFARE',
#  'GLOBAL REVIVAL MINISTRIES INC',
#  'TENDER SPROUT LEARNING CENTER INC',
#  'HUMANE EDUCATIONAL SOCIETY OF CHATTANOOGA TENN',
#  'CASA DE SARA',
#  'DANIEL BOONE BLAZER BAND',
#  'ADVENTURES WITH JESUS MINISTRIES WITH JOHN MILLER',
#  'FRANKLIN-WILLIAMSON COUNTY YOUTH FOOTBALL ASSOCIATION INC',
#  'YOU CAN MINISTRIES INC',
#  'RURAL ALABAMA HEALTH ALLIANCE',
#  'BOSHEARS MEMORIAL FLY-IN INC',
#  'CENTRAL BAND OF CHEROKEE',
#  'ACHIEVEMENT REWARDS FOR COLLEGE SCIENTISTS FOUNDATION INC OREGON',
#  'TAKING NEW TERRITORY-NOW MINISTRIES',
#  'TENNESSEE CHAPTER OF THE NATIONAL ASSOCIATION OF THE DUALLY',
#  'MOUNT ZION LITERATURE MINISTRIES',
#  'CHATTANOOGA WOMENS LEADERSHIP INSTITUTE',
#  'CREATIVE ARTISTS OF TENNESSEE INC',
#  'EFFINGHAM COUNTY VICTIM WITNESS ASSISTANCE PROGRAM',
#  'OUR PRIDE ENCOMPASSES NASHVILLE',
#  'TENNESSEE ASSOCIATION OF ADMINISTRATORS OF SPECIAL EDUCATIO',
#  'MANCHESTER AREA SENIOR CITIZENS',
#  'TENNESSEE ASSOCIATION FOR PUPIL TRANSPORTATION',
#  'TNVAL',
#  'ANGELS ON EARTH FOUNDATION',
#  'LITTLE HERITAGE ENRICHMENT CTR INC',
#  'SEQUATCHIE AREA VOLUNTEER FIRE ASSO INC',
#  'MCNAIRY-CHESTER CATTLEMANS ASSOCIATION',
#  'COALITION OF OAK RIDGE RETIRED EMPLOYEES',
#  'ALICE SWIM TEAM PARENTS CLUB',
#  'GOLDEN TRIANGLE RESOURCE CONSERVATI & DEVELOPMENT AREA INC',
#  'CENTRAL VALLEY PROSPECTORS-GPAA',
#  'ADVOCATES FOR THE OAK RIDGE RESERVATION',
#  'STAR VALLEY CHORAL CENTER',
#  'PHI BETA SIGMA FRATERNITY-ETA BETA SIGMA CHAPTER INCORPORATED',
#  'MEMPHIS CHAPTER ASSOCIATION OF LEGAL ADMINISTRATORS',
#  'JOY HOUSE MINISTRIES',
#  'SOUTHERN CALIFORNIA CONFERENCES FOR UNDERGRADUATE RESEARCH',
#  'COMFORT HOMESAKE INC',
#  'CAMDEN LIONS FOUNDATION INC',
#  'TENNESSEE BIOTECHNOLOGY ASSOCIATION',
#  'NORTH COUNTY ART ASSOCIATION',
#  'BUILDING TOWARD WELLNESS COMMUNITY COALITION INC',
#  'DEEP SOUTH CENTER FOR ENVIRONMENTAL JUSTICE',
#  'GOOD OLD DAYS PLAN OF REHABILITATION',
#  'BIBLE EDUCATION & MISSIONARY SERVICE',
#  'PEOPLE EMPOWERING PEOPLE PROJECT',
#  'ATLANTA TAIWANESE ASSOCIATION OF AMERICA INC',
#  'THE FLORIDA DISTRICT OF KIWANIS INTERNATIONAL INC',
#  'RIVERVIEW-ST MARYS INC',
#  'HONOR SOCIETY OF PHI KAPPA PHE',
#  'HONOR SOCIEY OF PHI KAPPA PHI',
#  'MOUNTAIN RIDGE LADY LIONS HOOPS CLUB',
#  'PET FLORIDA-PENNEY FARMS INC',
#  'A L S OF MIDDLE TENNESSEE',
#  'WORKFORCE RESOURCE INC',
#  'VETERANS OF FOREIGN WARS DEPARTMENT OF MISSISSIPPI',
#  'UNITED STATES VETERANS ARTISTS ALLIANCE',
#  'PUDDY TAT PROTECTORS INC',
#  'NORTH ALEXANDER SCHOOL ASSOCIATION INC',
#  'ROELLEN COMMUNITY CEMETERY FUND TR',
#  'SISKIYOU POLICE ACTIVITIES LEAGUE INC',
#  'WORD VOICE',
#  'BENTON HALL CORPORATION',
#  'VETERANS COMMUNITY EDUCATION PARTNERSHIP FOR WEST VOLUSIA INC',
#  'NATIONAL SOCIETY OF COLONIAL DAMES CAPTAIN CHARLES BARHAM CHAPTER',
#  'SHELBY COUNTY HEALTH CARE CORPORATION',
#  'KARNS ELEMENTARY PARENT TEACHER ASSOCIATION',
#  'UPPER CUMBERLAND BROADCAST COUNCIL',
#  'AMERICAN ORFF SCHULWERK ASSOCIATION',
#  'GEORGIAS OLD CAPITAL MUSEUM SOCIETY INC',
#  'THOSE THAT WAIT INCORPORATED',
#  'HUMANE LEAGUE OF LAKE LANIER INC',
#  'SAFE AMERICA FOUNDATION INC',
#  'MUSIC & ENTERTAINMENT INDUSTRY EDUCATORS ASSOCIATION MEIEA',
#  'VASA INC',
#  'FILIPINO - AMERICAN ASSOCIATION OF VOLUSIA COUNTY',
#  'COLLINS HILL ORCHESTRA BOOSTER ASSOCIATION',
#  'DOBYNS-BENNETT PTSA',
#  'ANNUAL TENNESSEE BEEF AGRIBITION',
#  'CHATTOOGA CONSERVANCY INC',
#  'LITTLE ROCK AIR FORCE BASE HISTORICAL FOUNDATION INC',
#  'PRO-LIFE MAJORITY COALITION OF CHATTANOOGA',
#  'WEECARE DAY CARE PROGRAM',
#  'GEORGIA HIGHLAND ASSOCIATION ROYAL ORDER OF SCOTLAND',
#  'ORPHEUM THEATRE GROUP',
#  'BOGUE CHITTO LINCOLN COUNTY COMMUNITY CENTER',
#  'CANNON COUNTY DIXIE YOUTH ASSOCIATION INC',
#  'IATSE LOCAL 16 TRAINING TRUST FUND',
#  'CLAIRMONT-LAVISTA TRIANGLE PARK INC',
#  'SOUTHWEST FLORIDA CHAPTER OF THE WEST VIRGINIA UNIVERSITY ALUMNI',
#  'OURKANSAS INC',
#  'SEMMSF A MISSOURI NONPROFIT CORPORATION',
#  'R S HAWTHORNE FAM CEMETERY TR',
#  'BELLINGHAM INTL FILM FESTIVAL',
#  'TRI-GRACE MINISTRIES INC',
#  'SARA & JAMES G PRATTIS ENDOWMENT FOUNDATION INC',
#  'SPEECH AND HEARING FOUNDATION OF THE MOUNTAIN REGION INC',
#  'MAGIC CITY BMX ASSOCIATION INC',
#  'CEDAR FORKS RECREATION ASSOCIATION INC',
#  'LOS ANGELES POLICE PROTECTIVE LEAGUE BENEFITS TRUST',
#  'EMERALD HODGSON HOSPITAL AUXILLIARY INC',
#  'MAGNOLIA STATE PEACE OFFICERS ASSOCIATION',
#  'LEBANON LODGE 98 FREE AND ACCEPTED MASONS OF TENNESSEE',
#  'SANCTUS',
#  'VETERANS OF FOREIGN WARS OF THE UNTIED STATES DEPT OF TENNESSEE',
#  'VETERANS OF FOREIGN WARS DEPARTMENT OF TENNESSEE',
#  'SENSING BROS POST NO 4641 VETERANS OF FOREIGN WARS',
#  'HILLCREST HEALTHCARE COMMUNITIES INC',
#  'COLORED PENCIL SOCIETY OF AMERICA',
#  'JORDAN FDN',
#  'LOCAL NO 43 PLUMBERS AND STEAMFITTERS JOINT APPRENTICESHIP',
#  'KNIGHTS OF COLUMBUS COUNCIL 5062 INC',
#  'MIDDLE TENNESSEE CHAPTER SOCIETY FOR HUMAN RESOURCE MANAGEMENT INC',
#  'WAYNE JOLLEY MINISTRIES INC',
#  'BTL-LMR EMPLOYEE BENEFIT PLAN TRUST',
#  'ADULT BASIC EDUCATION COUNCIL OF LAUDERDALE COUNTY TENNESSEE-ABE-',
#  'TENNESSEE PIPE TRADES ASSOCIATION',
#  'FLINT RIDGE F R A M P INC',
#  'NORTH CHICKAMAUGA CREEK CONSERVANCY',
#  'BLUES CITY RUNNERS',
#  'MUSIC CITY RECOVERY RESOURCES INC',
#  'MILAN MASONIC LODGE 393 A&FM',
#  'NOAHS ARK BAYOU SANCTUARY',
#  'LUVRIC',
#  'MAKE A DIFFERENCE MINISTRIES INC',
#  'KNOXVILLE CBID MANAGEMENT CORPORATION',
#  'GENERAL FEDERATED WOMANS CLUB OF HENDERSONVILLE',
#  'MISSIO INTERNATIONAL',
#  'NORTH AMERICAN BANGLADESHI ISLAMIC COMMUNITY',
#  'COMMUNITY HOUSING PARTNERSHIP OF WILLIAMSON COUNTY',
#  'SAFE ENVIRONMENT THROUGH COMMUNITY UNITY FOR RESPONSIBLE EDUCATION IN',
#  'TENNESSEE GEOGRAPHIC INFORMATION COUNCIL',
#  'LEARNING BLOCK PRESCHOOL DAYCARE',
#  'TREE BOARD OF MARTIN INC',
#  'FIRST TENNESSEE PRIVATE INDUSTRY COUNCIL INC',
#  'TENNESSEE PROFESSIONAL INVESTIGATORS ASSOCIATION',
#  'ARK-LA-TEX ANTIQUE AND CLASSIC VEHICLES INC',
#  'NEW LIFE RESOURCES INC',
#  'ALLEN MINISTRY SERVICES INC',
#  'GARNER MINISTRIES INC',
#  'NEW RAMAH PRIMITIVE BAPTIST CHURCH- CEMETERY CHARITABLE TR',
#  'DOVE COMMUNITY DEVELOPMENT INC',
#  'ANDREW JACKSON POLICE YOUTH CAMP',
#  'BRENTWOOD BLAZE INC',
#  'WOMAN AT THE WELL TRANSITION CENTER',
#  'HIGHLAND CEMETERY TRUST CORPORATION C/O JOE WALLACE TREASURER',
#  'HOMEWORK HOTLINE INC',
#  '100 BLACK MEN OF WEST GEORGIA INC',
#  'THE VOLUNTEERS OF AMERICAN CHARITY ORGANIZATION DRUG AND ALCOHOL',
#  '100 BLACK MEN OF MEMPHIS INC',
#  'THE COMMUNITY FOUNDATION FOR GREATER ATLANTA INC',
#  'UNITED MUSIC PEOPLE INC',
#  'TRUANCY INTERVENTION PROJECT GEORGIA INC',
#  'SOUTH EAST LAWYERS TENNESSEE LAWYERS ASSOCIATION FOR WOMEN',
#  'BENJAMIN HARDIN CHAPTER 366 USD 1812',
#  ...]

# %%
#Raplace names in the dataframe for any name repeated less than 10 times
for name in name_replace:
    application_df["NAME"]= application_df["NAME"].replace(name,"Other")

#Check name binning was succesful
application_df["NAME"].value_counts()
# Out:
# NAME
# Other                                      21022
# PARENT BOOSTER USA INC                      1260
# TOPS CLUB INC                                765
# UNITED STATES BOWLING CONGRESS INC           700
# WASHINGTON STATE UNIVERSITY                  492
#                                            ...
# CASCADE 4-H FOUNDATION                        10
# FREE & ACCEPTED MASONS OF WASHINGTON          10
# NEW MEXICO GARDEN CLUBS INC                   10
# NATIONAL ASSOCIATION OF HISPANIC NURSES       10
# UNION OF CALIFORNIA STATE WORKERS             10
# Name: count, Length: 223, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
print(application_type_counts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 500
application_types_to_replace = application_type_counts[application_type_counts < cutoff].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_type_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_type_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
common_classifications = classification_type_counts[classification_type_counts > 1]
print("\nCommon classifications (counts > 1):")
print(common_classifications)
# Out:
# Common classifications (counts > 1):
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value (e.g., less than 1500 occurrence)
cutoff = 1500

# Create a list of classifications to be replaced
classifications_to_replace = classification_type_counts[classification_type_counts < cutoff].index.tolist()

# Replace all values in the 'CLASSIFICATION' column matching the list with "Other"
application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].apply(
    lambda x: "Other" if x in classifications_to_replace else x
)

# Check to make sure replacement was successful
print(application_df['CLASSIFICATION'].value_counts())
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
print(application_df.dtypes)
# Out:
# NAME                      object
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
# Find the columns in the dataframe
print("Columns in DataFrame:", application_df.columns)
# Out:
# Columns in DataFrame: Index(['NAME', 'APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
#        'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS',
#        'ASK_AMT', 'IS_SUCCESSFUL'],
#       dtype='object')

# %%
columns_to_encode = ['NAME','APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION',
                     'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']

# Verify the columns exist in the DataFrame
missing_columns = [col for col in columns_to_encode if col not in application_df.columns]
if missing_columns:
    print(f"Warning: These columns are missing from the DataFrame: {missing_columns}")
else:
    # Apply get_dummies to the specified columns
    application_df_dummies = pd.get_dummies(application_df, columns=columns_to_encode)
    print(application_df_dummies.head())
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  NAME_ACE MENTOR PROGRAM OF AMERICA INC  \
# 0       1     5000              1                                   False
# 1       1   108590              1                                   False
# 2       1     5000              0                                   False
# 3       1     6692              1                                   False
# 4       1   142590              1                                   False
#
#    NAME_AIR FORCE ASSOCIATION  NAME_ALABAMA FEDERATION OF WOMENS CLUBS  \
# 0                       False                                    False
# 1                       False                                    False
# 2                       False                                    False
# 3                       False                                    False
# 4                       False                                    False
#
#    NAME_ALABAMA TREASURE FOREST ASSOCIATION  NAME_ALPHA PHI SIGMA  \
# 0                                     False                 False
# 1                                     False                 False
# 2                                     False                 False
# 3                                     False                 False
# 4                                     False                 False
#
#    NAME_ALPHA PHI SIGMA INC  NAME_ALTRUSA INTERNATIONAL FOUNDATION INC  ...  \
# 0                     False                                      False  ...
# 1                     False                                      False  ...
# 2                     False                                      False  ...
# 3                     False                                      False  ...
# 4                     False                                      False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 267 columns]

# %%
# Split our preprocessed data into our features and target arrays
# Features for training "X"
X = application_df_dummies.drop("IS_SUCCESSFUL", axis=1).values

# Target for the training "y"

y = application_df_dummies["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
#understand the shape of the X_train
X_train.shape
# Out:
# (25724, 266)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features= len(X_train_scaled[0])
hidden_layer_node1=80
hidden_layer_node2=30

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_layer_node1, activation="relu", input_dim=number_input_features))
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_layer_node2, activation="relu"))
# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))
# Check the structure of the model
nn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 80)                  │          21,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 30)                  │           2,430 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              31 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,821 (93.05 KB)
#  Trainable params: 23,821 (93.05 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7494 - loss: 0.5174
# Epoch 2/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7861 - loss: 0.4433
# Epoch 3/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7847 - loss: 0.4444
# Epoch 4/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7865 - loss: 0.4372
# Epoch 5/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7881 - loss: 0.4373
# Epoch 6/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7856 - loss: 0.4361
# Epoch 7/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7942 - loss: 0.4334
# Epoch 8/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7914 - loss: 0.4356
# Epoch 9/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7875 - loss: 0.4338
# Epoch 10/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7951 - loss: 0.4278
# Epoch 11/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7913 - loss: 0.4377
# Epoch 12/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7911 - loss: 0.4327
# Epoch 13/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7893 - loss: 0.4313
# Epoch 14/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7955 - loss: 0.4283
# Epoch 15/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7930 - loss: 0.4292
# Epoch 16/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7993 - loss: 0.4232
# Epoch 17/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7958 - loss: 0.4264
# Epoch 18/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7966 - loss: 0.4279
# Epoch 19/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7916 - loss: 0.4326
# Epoch 20/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7963 - loss: 0.4247
# Epoch 21/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7960 - loss: 0.4244
# Epoch 22/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7927 - loss: 0.4280
# Epoch 23/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8010 - loss: 0.4215
# Epoch 24/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7898 - loss: 0.4324
# Epoch 25/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7965 - loss: 0.4260
# Epoch 26/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7941 - loss: 0.4244
# Epoch 27/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7981 - loss: 0.4212
# Epoch 28/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7998 - loss: 0.4186
# Epoch 29/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7981 - loss: 0.4226
# Epoch 30/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7979 - loss: 0.4241
# Epoch 31/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7945 - loss: 0.4271
# Epoch 32/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7951 - loss: 0.4225
# Epoch 33/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7951 - loss: 0.4248
# Epoch 34/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7961 - loss: 0.4255
# Epoch 35/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7950 - loss: 0.4222
# Epoch 36/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7958 - loss: 0.4215
# Epoch 37/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7986 - loss: 0.4216
# Epoch 38/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7989 - loss: 0.4207
# Epoch 39/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7931 - loss: 0.4269
# Epoch 40/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7987 - loss: 0.4166
# Epoch 41/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7976 - loss: 0.4208
# Epoch 42/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7979 - loss: 0.4220
# Epoch 43/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7968 - loss: 0.4207
# Epoch 44/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7997 - loss: 0.4146
# Epoch 45/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4235
# Epoch 46/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7981 - loss: 0.4208
# Epoch 47/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7999 - loss: 0.4206
# Epoch 48/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7942 - loss: 0.4249
# Epoch 49/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7986 - loss: 0.4178
# Epoch 50/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7940 - loss: 0.4246
# Epoch 51/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7996 - loss: 0.4188
# Epoch 52/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7945 - loss: 0.4223
# Epoch 53/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7999 - loss: 0.4188
# Epoch 54/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7986 - loss: 0.4232
# Epoch 55/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8007 - loss: 0.4148
# Epoch 56/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8029 - loss: 0.4185
# Epoch 57/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7947 - loss: 0.4210
# Epoch 58/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7980 - loss: 0.4194
# Epoch 59/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7954 - loss: 0.4196
# Epoch 60/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7993 - loss: 0.4175
# Epoch 61/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7978 - loss: 0.4176
# Epoch 62/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7988 - loss: 0.4167
# Epoch 63/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7965 - loss: 0.4209
# Epoch 64/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7991 - loss: 0.4173
# Epoch 65/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7954 - loss: 0.4207
# Epoch 66/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8018 - loss: 0.4121
# Epoch 67/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7984 - loss: 0.4183
# Epoch 68/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7963 - loss: 0.4196
# Epoch 69/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8004 - loss: 0.4151
# Epoch 70/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8016 - loss: 0.4156
# Epoch 71/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8019 - loss: 0.4146
# Epoch 72/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8001 - loss: 0.4162
# Epoch 73/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8002 - loss: 0.4130
# Epoch 74/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8000 - loss: 0.4172
# Epoch 75/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7979 - loss: 0.4204
# Epoch 76/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7984 - loss: 0.4168
# Epoch 77/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7981 - loss: 0.4193
# Epoch 78/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7962 - loss: 0.4184
# Epoch 79/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7998 - loss: 0.4161
# Epoch 80/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8015 - loss: 0.4177
# Epoch 81/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7996 - loss: 0.4188
# Epoch 82/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7970 - loss: 0.4172
# Epoch 83/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7983 - loss: 0.4189
# Epoch 84/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7990 - loss: 0.4174
# Epoch 85/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7971 - loss: 0.4206
# Epoch 86/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7919 - loss: 0.4239
# Epoch 87/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7990 - loss: 0.4177
# Epoch 88/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7967 - loss: 0.4212
# Epoch 89/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7970 - loss: 0.4191
# Epoch 90/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8035 - loss: 0.4102
# Epoch 91/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7967 - loss: 0.4209
# Epoch 92/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7968 - loss: 0.4197
# Epoch 93/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8013 - loss: 0.4172
# Epoch 94/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7925 - loss: 0.4231
# Epoch 95/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7992 - loss: 0.4156
# Epoch 96/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7935 - loss: 0.4219
# Epoch 97/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7998 - loss: 0.4136
# Epoch 98/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8008 - loss: 0.4148
# Epoch 99/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7997 - loss: 0.4132
# Epoch 100/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8022 - loss: 0.4150

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - 2ms/step - accuracy: 0.7791 - loss: 0.4704
# Loss: 0.4704497456550598, Accuracy: 0.7791253924369812

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("./AlphabetSoupCharity_Optimization.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import files
files.download("AlphabetSoupCharity_Optimization.h5")

# %% [markdown]
# Optimizing the model for more accuracy

# %%
#Optimization 1 - Adding more nodes
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features= len(X_train_scaled[0])
hidden_layer_node1=40
hidden_layer_node2=20
hidden_layer_node3=10

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_layer_node1, activation="relu", input_dim=number_input_features))
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_layer_node2, activation="relu"))
# Third hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_layer_node3, activation="relu"))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                      │ (None, 40)                  │           1,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 20)                  │             820 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,801 (10.94 KB)
#  Trainable params: 2,801 (10.94 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6865 - loss: 0.6118
# Epoch 2/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7284 - loss: 0.5557
# Epoch 3/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7307 - loss: 0.5539
# Epoch 4/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7356 - loss: 0.5488
# Epoch 5/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7293 - loss: 0.5527
# Epoch 6/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7339 - loss: 0.5457
# Epoch 7/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7415 - loss: 0.5383
# Epoch 8/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7365 - loss: 0.5460
# Epoch 9/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7333 - loss: 0.5464
# Epoch 10/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7368 - loss: 0.5442
# Epoch 11/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7309 - loss: 0.5511
# Epoch 12/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7408 - loss: 0.5397
# Epoch 13/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7406 - loss: 0.5371
# Epoch 14/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7387 - loss: 0.5416
# Epoch 15/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7433 - loss: 0.5363
# Epoch 16/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7351 - loss: 0.5430
# Epoch 17/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7367 - loss: 0.5447
# Epoch 18/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7379 - loss: 0.5426
# Epoch 19/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7376 - loss: 0.5417
# Epoch 20/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7357 - loss: 0.5429
# Epoch 21/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7356 - loss: 0.5467
# Epoch 22/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7405 - loss: 0.5418
# Epoch 23/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7399 - loss: 0.5388
# Epoch 24/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7361 - loss: 0.5406
# Epoch 25/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7298 - loss: 0.5496
# Epoch 26/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7416 - loss: 0.5374
# Epoch 27/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7399 - loss: 0.5390
# Epoch 28/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7379 - loss: 0.5378
# Epoch 29/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7385 - loss: 0.5409
# Epoch 30/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7424 - loss: 0.5371
# Epoch 31/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7341 - loss: 0.5441
# Epoch 32/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7401 - loss: 0.5393
# Epoch 33/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7395 - loss: 0.5383
# Epoch 34/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7400 - loss: 0.5376
# Epoch 35/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7420 - loss: 0.5356
# Epoch 36/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7409 - loss: 0.5370
# Epoch 37/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7472 - loss: 0.5322
# Epoch 38/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7446 - loss: 0.5329
# Epoch 39/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7411 - loss: 0.5324
# Epoch 40/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7397 - loss: 0.5389
# Epoch 41/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7405 - loss: 0.5387
# Epoch 42/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7376 - loss: 0.5387
# Epoch 43/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7454 - loss: 0.5332
# Epoch 44/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7383 - loss: 0.5385
# Epoch 45/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7384 - loss: 0.5386
# Epoch 46/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7358 - loss: 0.5423
# Epoch 47/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7420 - loss: 0.5348
# Epoch 48/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7395 - loss: 0.5386
# Epoch 49/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7357 - loss: 0.5413
# Epoch 50/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7376 - loss: 0.5410
# Epoch 51/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7418 - loss: 0.5375
# Epoch 52/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7435 - loss: 0.5333
# Epoch 53/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7418 - loss: 0.5335
# Epoch 54/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7392 - loss: 0.5377
# Epoch 55/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7443 - loss: 0.5330
# Epoch 56/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7378 - loss: 0.5382
# Epoch 57/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7409 - loss: 0.5347
# Epoch 58/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7439 - loss: 0.5303
# Epoch 59/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7366 - loss: 0.5407
# Epoch 60/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7413 - loss: 0.5320
# Epoch 61/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7421 - loss: 0.5363
# Epoch 62/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7434 - loss: 0.5344
# Epoch 63/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7424 - loss: 0.5362
# Epoch 64/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7423 - loss: 0.5319
# Epoch 65/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7403 - loss: 0.5367
# Epoch 66/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7347 - loss: 0.5396
# Epoch 67/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7424 - loss: 0.5349
# Epoch 68/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7411 - loss: 0.5357
# Epoch 69/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7419 - loss: 0.5337
# Epoch 70/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7392 - loss: 0.5381
# Epoch 71/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7419 - loss: 0.5358
# Epoch 72/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7411 - loss: 0.5356
# Epoch 73/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7433 - loss: 0.5344
# Epoch 74/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7390 - loss: 0.5346
# Epoch 75/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7363 - loss: 0.5377
# Epoch 76/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7382 - loss: 0.5369
# Epoch 77/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7384 - loss: 0.5377
# Epoch 78/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7381 - loss: 0.5361
# Epoch 79/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7415 - loss: 0.5338
# Epoch 80/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7416 - loss: 0.5354
# Epoch 81/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7409 - loss: 0.5361
# Epoch 82/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7389 - loss: 0.5402
# Epoch 83/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7471 - loss: 0.5330
# Epoch 84/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7464 - loss: 0.5315
# Epoch 85/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7402 - loss: 0.5346
# Epoch 86/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7417 - loss: 0.5329
# Epoch 87/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7386 - loss: 0.5375
# Epoch 88/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7377 - loss: 0.5389
# Epoch 89/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7430 - loss: 0.5336
# Epoch 90/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7420 - loss: 0.5329
# Epoch 91/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7398 - loss: 0.5366
# Epoch 92/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7417 - loss: 0.5317
# Epoch 93/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7392 - loss: 0.5347
# Epoch 94/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7419 - loss: 0.5350
# Epoch 95/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7373 - loss: 0.5385
# Epoch 96/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7435 - loss: 0.5310
# Epoch 97/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7468 - loss: 0.5299
# Epoch 98/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7421 - loss: 0.5337
# Epoch 99/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7403 - loss: 0.5348
# Epoch 100/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7390 - loss: 0.5355

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - 2ms/step - accuracy: 0.7248 - loss: 0.5666
# Loss: 0.5665773153305054, Accuracy: 0.724781334400177
